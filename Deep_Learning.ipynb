# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanjinathan23/Deep-Learning/blob/main/Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Dataset
data = {
    'Hours':[1,2,3,4,5,6],
    'Marks':[35,45,55,65,75,85]
}

df = pd.DataFrame(data)

X = df[['Hours']]
y = df['Marks']

# Create model
model = LinearRegression()

# Train model
model.fit(X,y)

# Predict marks for 7 hours
prediction = model.predict([[7]])

print("Predicted Marks:",prediction[0])
# Out:
# Predicted Marks: 95.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {
    'Hours': [0, 1, 2, 3, 4, 5, 6],
    'Battery_Percentage': [100, 92, 84, 76, 68, 60, 52]
}

df = pd.DataFrame(data)

X = df[['Hours']]

y = df['Battery_Percentage']

model = LinearRegression()

model.fit(X, y)

prediction = model.predict([[3]])

print("Predicted Battery Percentage after 3 hours:", prediction[0])
# Out:
# Predicted Battery Percentage after 3 hours: 76.0
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# Dataset
data = {
    'Battery': [95, 90, 85, 80, 40, 35, 30, 25],
    'Status': ['Good', 'Good', 'Good', 'Good', 'Low', 'Low', 'Low', 'Low']
}

df = pd.DataFrame(data)

X = df[['Battery']]
y = df['Status']

# Create model
model = KNeighborsClassifier(n_neighbors=3)

# Train model
model.fit(X, y)

# Predict battery status for 50%
prediction = model.predict([[50]])

print("Predicted Battery Status:", prediction[0])
# Out:
# Predicted Battery Status: Low
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# Dataset
data = {
    'Marks': [35, 40, 45, 50, 75, 80, 85, 90],
    'Result': ['Fail', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass']
}

df = pd.DataFrame(data)

X = df[['Marks']]
y = df['Result']

# Create model
model = KNeighborsClassifier(n_neighbors=3)

# Train model
model.fit(X, y)

# Predict for 48 marks
prediction = model.predict([[48]])

print("Predicted Result:", prediction[0])
# Out:
# Predicted Result: Fail
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# Dataset
data = {
    'Price': [10000, 12000, 15000, 18000, 50000, 55000, 60000, 70000],
    'Category': ['Budget', 'Budget', 'Budget', 'Budget',
                 'Premium', 'Premium', 'Premium', 'Premium']
}

df = pd.DataFrame(data)

X = df[['Price']]
y = df['Category']

# Create model
model = KNeighborsClassifier(n_neighbors=3)

# Train model
model.fit(X, y)

# Predict category for ₹20,000
prediction = model.predict([[20000]])

print("Predicted Category:", prediction[0])
# Out:
# Predicted Category: Budget
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

# Sample data (heights in cm)
heights = np.array([160, 162, 165, 170, 168,
                    172, 169, 171, 167, 166])

# Maximum Likelihood Estimate of Mean
mean_mle = np.mean(heights)

# Maximum Likelihood Estimate of Variance
variance_mle = np.mean((heights - mean_mle) ** 2)

print("MLE Mean =", mean_mle)
print("MLE Variance =", variance_mle)
# Out:
# MLE Mean = 167.0
# MLE Variance = 13.4

# %%
import numpy as np
from scipy.optimize import minimize_scalar
import scipy.stats as stats


heads = 7
tosses = 10


p_mle_direct = heads / tosses
print(f"Direct MLE Probability: {p_mle_direct:.4f}")


def negative_log_likelihood(p):

    if p <= 0 or p >= 1:
        return np.inf

    return -stats.binom.logpmf(heads, tosses, p)


result = minimize_scalar(negative_log_likelihood, bounds=(0, 1), method='bounded')
print(f"Numerical MLE Probability: {result.x:.4f}")
# Out:
# Direct MLE Probability: 0.7000
# Numerical MLE Probability: 0.7000

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier

data = {
    "Study_Hours": [2, 3, 5, 6, 8],
    "Attendance": [60, 65, 80, 85, 95],
    "Assignment": [50, 55, 70, 80, 90],
    "Result": [0, 0, 1, 1, 1]
}

df = pd.DataFrame(data)

X = df[["Study_Hours", "Attendance", "Assignment"]]

y = df["Result"]

model = MLPClassifier(hidden_layer_sizes=(4,),
                      max_iter=2000,
                      random_state=42)

model.fit(X, y)

prediction = model.predict([[4, 75, 65]])

if prediction[0] == 1:
    print("Student Will Pass")
else:
    print("Student Will Fail")
# Out:
# Student Will Fail
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
